# %% [markdown]
# # Task 4.4

# %%
# Import librairies
import pandas as pd
import numpy as np
import os

# %%
path = r'C:\Users\salmi\Desktop\Projects\Achievement 4\Instacart Basket Analysis'

# %% [markdown]
# #### Dataframe objects: df_ords = orders csv / df_prods = products csv

# %%
df_ords = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'orders.csv'), index_col = False)

# %%
df_prods = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'products.csv'), index_col = False)

# %%
print(df_ords.columns)
# Out:
# Index(['order_id', 'user_id', 'eval_set', 'order_number', 'order_dow',
#        'order_hour_of_day', 'days_since_prior_order'],
#       dtype='object')

# %%
print(df_prods.columns)
# Out:
# Index(['product_id', 'product_name', 'aisle_id', 'department_id', 'prices'], dtype='object')

# %%
df_ords=df_ords.drop(columns=['eval_set'])

# %%
df_ords
# Out:
#          order_id  user_id  order_number  order_dow  order_hour_of_day  \
# 0         2539329        1             1          2                  8
# 1         2398795        1             2          3                  7
# 2          473747        1             3          3                 12
# 3         2254736        1             4          4                  7
# 4          431534        1             5          4                 15
# ...           ...      ...           ...        ...                ...
# 3421078   2266710   206209            10          5                 18
# 3421079   1854736   206209            11          4                 10
# 3421080    626363   206209            12          1                 12
# 3421081   2977660   206209            13          1                 12
# 3421082    272231   206209            14          6                 14
#
#          days_since_prior_order
# 0                           NaN
# 1                          15.0
# ...

# %%
df_ords ['days_since_prior_order'].value_counts(dropna = False)
# Out:
# days_since_prior_order
# 30.0    369323
# 7.0     320608
# 6.0     240013
# 4.0     221696
# 3.0     217005
# 5.0     214503
# NaN     206209
# 2.0     193206
# 8.0     181717
# 1.0     145247
# 9.0     118188
# 14.0    100230
# 10.0     95186
# 13.0     83214
# 11.0     80970
# 12.0     76146
# 0.0      67755
# 15.0     66579
# 16.0     46941
# 21.0     45470
# 17.0     39245
# 20.0     38527
# 18.0     35881
# 19.0     34384
# 22.0     32012
# 28.0     26777
# 23.0     23885
# 27.0     22013
# 24.0     20712
# 25.0     19234
# 29.0     19191
# 26.0     19016
# Name: count, dtype: int64

# %%
# Renaming of the column order_dow to orders_day_of_week
df_ords.rename(columns = {'order_dow' : 'orders_day_of_week'}, inplace = True)

# %%
df_ords
# Out:
#          order_id  user_id  order_number  orders_day_of_week  \
# 0         2539329        1             1                   2
# 1         2398795        1             2                   3
# 2          473747        1             3                   3
# 3         2254736        1             4                   4
# 4          431534        1             5                   4
# ...           ...      ...           ...                 ...
# 3421078   2266710   206209            10                   5
# 3421079   1854736   206209            11                   4
# 3421080    626363   206209            12                   1
# 3421081   2977660   206209            13                   1
# 3421082    272231   206209            14                   6
#
#          order_hour_of_day  days_since_prior_order
# 0                        8                     NaN
# 1                        7                    15.0
# 2                       12                    21.0
# ...

# %%
# Changing data types of column order_id
df_ords['order_id'] = df_ords['order_id'].astype('str')

# %%
df_ords['order_id'].dtype
# Out:
# dtype('O')

# %%
# Importing data set departments.csv
df_dep = pd.read_csv(os.path.join(path, '02 Data', 'Original Data', 'departments.csv'), index_col = False)

# %%
df_dep
# Out:
#   department_id       1      2       3        4        5              6  \
# 0    department  frozen  other  bakery  produce  alcohol  international
#
#            7     8                9  ...            12      13         14  \
# 0  beverages  pets  dry goods pasta  ...  meat seafood  pantry  breakfast
#
#              15          16         17      18      19    20       21
# 0  canned goods  dairy eggs  household  babies  snacks  deli  missing
#
# [1 rows x 22 columns]

# %%
# Transposing df_dep
df_dep.T
# Out:
#                              0
# department_id       department
# 1                       frozen
# 2                        other
# 3                       bakery
# 4                      produce
# 5                      alcohol
# 6                international
# 7                    beverages
# 8                         pets
# 9              dry goods pasta
# 10                        bulk
# 11               personal care
# 12                meat seafood
# 13                      pantry
# 14                   breakfast
# 15                canned goods
# 16                  dairy eggs
# 17                   household
# 18                      babies
# 19                      snacks
# 20                        deli
# 21                     missing

# %%
df_dep_t = df_dep.T

# %%
df_dep_t
# Out:
#                              0
# department_id       department
# 1                       frozen
# 2                        other
# 3                       bakery
# 4                      produce
# 5                      alcohol
# 6                international
# 7                    beverages
# 8                         pets
# 9              dry goods pasta
# 10                        bulk
# 11               personal care
# 12                meat seafood
# 13                      pantry
# 14                   breakfast
# 15                canned goods
# 16                  dairy eggs
# 17                   household
# 18                      babies
# 19                      snacks
# 20                        deli
# 21                     missing

# %%
df_dep_t.reset_index()
# Out:
#             index                0
# 0   department_id       department
# 1               1           frozen
# 2               2            other
# 3               3           bakery
# 4               4          produce
# 5               5          alcohol
# 6               6    international
# 7               7        beverages
# 8               8             pets
# 9               9  dry goods pasta
# 10             10             bulk
# 11             11    personal care
# 12             12     meat seafood
# 13             13           pantry
# 14             14        breakfast
# 15             15     canned goods
# 16             16       dairy eggs
# 17             17        household
# 18             18           babies
# 19             19           snacks
# 20             20             deli
# 21             21          missing

# %%
# Tkae the first row of df_dep_t for the headed
new_header = df_dep_t.iloc[0]

# %%
new_header
# Out:
# 0    department
# Name: department_id, dtype: object

# %%
# Take the data under the header row for a new df
df_dep_t_new = df_dep_t[1:]

# %%
df_dep_t_new
# Out:
#                   0
# 1            frozen
# 2             other
# 3            bakery
# 4           produce
# 5           alcohol
# 6     international
# 7         beverages
# 8              pets
# 9   dry goods pasta
# 10             bulk
# 11    personal care
# 12     meat seafood
# 13           pantry
# 14        breakfast
# 15     canned goods
# 16       dairy eggs
# 17        household
# 18           babies
# 19           snacks
# 20             deli
# 21          missing

# %%
df_dep_t_new.columns = new_header # set the header row as the df header

# %%
df_dep_t_new
# Out:
# department_id       department
# 1                       frozen
# 2                        other
# 3                       bakery
# 4                      produce
# 5                      alcohol
# 6                international
# 7                    beverages
# 8                         pets
# 9              dry goods pasta
# 10                        bulk
# 11               personal care
# 12                meat seafood
# 13                      pantry
# 14                   breakfast
# 15                canned goods
# 16                  dairy eggs
# 17                   household
# 18                      babies
# 19                      snacks
# 20                        deli
# 21                     missing

# %%
data_dict = df_dep_t_new.to_dict('index') # creation of the data dictionnary

# %%
data_dict
# Out:
# {'1': {'department': 'frozen'},
#  '2': {'department': 'other'},
#  '3': {'department': 'bakery'},
#  '4': {'department': 'produce'},
#  '5': {'department': 'alcohol'},
#  '6': {'department': 'international'},
#  '7': {'department': 'beverages'},
#  '8': {'department': 'pets'},
#  '9': {'department': 'dry goods pasta'},
#  '10': {'department': 'bulk'},
#  '11': {'department': 'personal care'},
#  '12': {'department': 'meat seafood'},
#  '13': {'department': 'pantry'},
#  '14': {'department': 'breakfast'},
#  '15': {'department': 'canned goods'},
#  '16': {'department': 'dairy eggs'},
#  '17': {'department': 'household'},
#  '18': {'department': 'babies'},
#  '19': {'department': 'snacks'},
#  '20': {'department': 'deli'},
#  '21': {'department': 'missing'}}

# %%
df_prods.head()
# Out:
#    product_id                                       product_name  aisle_id  \
# 0           1                         Chocolate Sandwich Cookies        61
# 1           2                                   All-Seasons Salt       104
# 2           3               Robust Golden Unsweetened Oolong Tea        94
# 3           4  Smart Ones Classic Favorites Mini Rigatoni Wit...        38
# 4           5                          Green Chile Anytime Sauce         5
#
#    department_id  prices
# 0             19     5.8
# 1             13     9.3
# 2              7     4.5
# 3              1    10.5
# 4             13     4.3

# %%
print (data_dict.get('19'))
# Out:
# {'department': 'snacks'}

# %%
df_snacks = df_prods[df_prods['department_id']==19] #dataframe for snacks department

# %%
df_prods['department_id']==19
# Out:
# 0         True
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 49688    False
# 49689    False
# 49690    False
# 49691    False
# 49692    False
# Name: department_id, Length: 49693, dtype: bool

# %%
df_prods[df_prods['department_id']==19]
# Out:
#        product_id                                   product_name  aisle_id  \
# 0               1                     Chocolate Sandwich Cookies        61
# 15             16                  Mint Chocolate Flavored Syrup       103
# 24             25        Salted Caramel Lean Protein & Fiber Bar         3
# 31             32                  Nacho Cheese White Bean Chips       107
# 40             41    Organic Sourdough Einkorn Crackers Rosemary        78
# ...           ...                                            ...       ...
# 49666       49662                   Bacon Cheddar Pretzel Pieces       107
# 49669       49665  Super Dark Coconut Ash & Banana Chocolate Bar        45
# 49670       49666                  Ginger Snaps Snacking Cookies        61
# 49675       49671                           Milk Chocolate Drops        45
# 49683       49679                        Famous Chocolate Wafers        61
#
#        department_id  prices
# 0                 19     5.8
# ...

# %%
df_snacks.head()
# Out:
#     product_id                                 product_name  aisle_id  \
# 0            1                   Chocolate Sandwich Cookies        61
# 15          16                Mint Chocolate Flavored Syrup       103
# 24          25      Salted Caramel Lean Protein & Fiber Bar         3
# 31          32                Nacho Cheese White Bean Chips       107
# 40          41  Organic Sourdough Einkorn Crackers Rosemary        78
#
#     department_id  prices
# 0              19     5.8
# 15             19     5.2
# 24             19     1.9
# 31             19     4.9
# 40             19     6.5

# %% [markdown]
# # Task 4.4

# %%
# Changing data types for user_id, order_hour_of_day, orders_day_of_week for the data frame df_ords
df_ords[['user_id', 'order_hour_of_day', 'orders_day_of_week']] = df_ords[['user_id', 'order_hour_of_day', 'orders_day_of_week']].astype(str)

# %%
df_ords.dtypes
# Out:
# order_id                   object
# user_id                    object
# order_number                int64
# orders_day_of_week         object
# order_hour_of_day          object
# days_since_prior_order    float64
# dtype: object

# %%
# Renaming the column order_number to order_amount
df_ords.rename(columns = {'order_number' : 'order_amount'}, inplace = True)

# %%
df_ords
# Out:
#         order_id user_id  order_amount orders_day_of_week order_hour_of_day  \
# 0        2539329       1             1                  2                 8
# 1        2398795       1             2                  3                 7
# 2         473747       1             3                  3                12
# 3        2254736       1             4                  4                 7
# 4         431534       1             5                  4                15
# ...          ...     ...           ...                ...               ...
# 3421078  2266710  206209            10                  5                18
# 3421079  1854736  206209            11                  4                10
# 3421080   626363  206209            12                  1                12
# 3421081  2977660  206209            13                  1                12
# 3421082   272231  206209            14                  6                14
#
#          days_since_prior_order
# ...

# %% [markdown]
# #### Finding the busiest hour for placing orders

# %%
# Calculation of the frequency of orders for each hour
order_hour_frequency = df_ords['order_hour_of_day'].value_counts().sort_index()

# %%
print(order_hour_frequency)
# Out:
# order_hour_of_day
# 0      22758
# 1      12398
# 10    288418
# 11    284728
# 12    272841
# 13    277999
# 14    283042
# 15    283639
# 16    272553
# 17    228795
# 18    182912
# 19    140569
# 2       7539
# 20    104292
# 21     78109
# 22     61468
# 23     40043
# 3       5474
# 4       5527
# 5       9569
# 6      30529
# 7      91868
# 8     178201
# 9     257812
# Name: count, dtype: int64

# %%
max_orders = order_hour_frequency.max() # find the maximum number of order

# %%
print (max_orders)
# Out:
# 288418

# %%
busy_hour = order_hour_frequency.idxmax() # find the busiest hour in which the orders amount is the highest

# %%
print (busy_hour)
# Out:
# 10

# %%
data_dict # department id and their names
# Out:
# {'1': {'department': 'frozen'},
#  '2': {'department': 'other'},
#  '3': {'department': 'bakery'},
#  '4': {'department': 'produce'},
#  '5': {'department': 'alcohol'},
#  '6': {'department': 'international'},
#  '7': {'department': 'beverages'},
#  '8': {'department': 'pets'},
#  '9': {'department': 'dry goods pasta'},
#  '10': {'department': 'bulk'},
#  '11': {'department': 'personal care'},
#  '12': {'department': 'meat seafood'},
#  '13': {'department': 'pantry'},
#  '14': {'department': 'breakfast'},
#  '15': {'department': 'canned goods'},
#  '16': {'department': 'dairy eggs'},
#  '17': {'department': 'household'},
#  '18': {'department': 'babies'},
#  '19': {'department': 'snacks'},
#  '20': {'department': 'deli'},
#  '21': {'department': 'missing'}}

# %% [markdown]
# #### Finding more about breakfast item sales

# %%
df_breakfast = df_prods[df_prods['department_id']==14]

# %%
df_prods[df_prods['department_id']==14]
# Out:
#        product_id                                       product_name  \
# 27             28                                  Wheat Chex Cereal
# 33             34                                                NaN
# 67             68                            Pancake Mix, Buttermilk
# 89             90                                       Smorz Cereal
# 210           211   Gluten Free Organic Cereal Coconut Maple Vanilla
# ...           ...                                                ...
# 49330       49326                            Cereal Variety Fun Pack
# 49395       49391            Light and Fluffy Buttermilk Pancake Mix
# 49547       49543                          Chocolate Cheerios Cereal
# 49637       49633               Shake 'N Pour Buttermilk Pancake Mix
# 49667       49663  Ultra Protein Power Crunch Peanut Butter N' Ho...
#
#        aisle_id  department_id  prices
# 27          121             14    10.1
# 33          121             14    12.2
# ...

# %%
df_breakfast ['prices'].describe() # descriptive statistics on sales for the breakfast department
# Out:
# count    1116.000000
# mean        7.848208
# std         3.971678
# min         1.000000
# 25%         4.400000
# 50%         7.700000
# 75%        11.300000
# max        14.900000
# Name: prices, dtype: float64

# %%
max_price_idx= df_breakfast ['prices'].idxmax() #Find the most expensive item

# %%
max_price_dep_14 = df_breakfast.loc[max_price_idx] #find the details of the most expensive item

# %%
print(max_price_dep_14)
# Out:
# product_id                                      3225
# product_name     Risin' Raisin Ancient Grains Cereal
# aisle_id                                         121
# department_id                                     14
# prices                                          14.9
# Name: 3225, dtype: object

# %%
min_price_idx= df_breakfast ['prices'].idxmin() #Find the cheapest item

# %%
min_price_dep_14 = df_breakfast.loc[min_price_idx] #find the details of the cheapest item

# %%
print(min_price_dep_14)
# Out:
# product_id                        12806
# product_name     French Vanilla Granola
# aisle_id                             57
# department_id                        14
# prices                              1.0
# Name: 12806, dtype: object

# %% [markdown]
# #### Details for party products: alcohol, deli, beverages, meat/seafood

# %%
df_party = df_prods.loc[df_prods['department_id'].isin([5,7,12,20])]

# %%
df_party
# Out:
#        product_id                                    product_name  aisle_id  \
# 2               3            Robust Golden Unsweetened Oolong Tea        94
# 6               7                  Pure Coconut Water With Orange        98
# 9              10  Sparkling Orange Juice & Prickly Pear Beverage       115
# 10             11                               Peach Mango Juice        31
# 16             17                               Rendered Duck Fat        35
# ...           ...                                             ...       ...
# 49676       49672                          Cafe Mocha K-Cup Packs        26
# 49679       49675             Cinnamon Dolce Keurig Brewed K Cups        26
# 49680       49676                          Ultra Red Energy Drink        64
# 49686       49682                              California Limeade        98
# 49688       49684       Vodka, Triple Distilled, Twist of Vanilla       124
#
#        department_id  prices
# ...

# %%
df_party_sorted_desc= df_party.sort_values(by='prices', ascending=False)

# %%
df_party_sorted_asc= df_party.sort_values(by='prices', ascending=True)

# %%
df_party_sorted_desc.head(50) # find the 50 most expensive items
# Out:
#        product_id                                       product_name  \
# 19392       19391                          Turkey Breast Tenderloins
# 25580       25579                      Naturally Smoked Trout Fillet
# 40490       40486                                    Chicken Tenders
# 21468       21467                             Wild Caught Raw Shrimp
# 9020         9020                   Boneless Skinless Chicken Thighs
# 41097       41093                           Sugar Free Dry Rub Bacon
# 14207       14207                                   Angus Roast Beef
# 9896         9896                     Uncured Applewood Smoked Bacon
# 39050       39046                            Smok Cured Turkey Bacon
# 48343       48339                                      Lobster Tails
# 36577       36573                                     Peppered Bacon
# 33987       33985                                   Sausage, Chorizo
# 22193       22192                                   Lite Beef Franks
# ...

# %%
df_party_sorted_asc.head(50) # find the 50 cheapest items
# Out:
#        product_id                                       product_name  \
# 45770       45766                                  Original Beverage
# 40684       40680                   Vanilla Double Shot Energy Drink
# 39929       39925  Grand-Mere Pork & Chicken Liver Pate With Arma...
# 38559       38555                                Amber Alt Style Ale
# 29315       29313                                  Non-Alcohoic Beer
# 48176       48172                  Culture Club Kombucha Goji Ginger
# 42345       42341  5 Antioxidant Infusions Sumatra Dragonfruit Drink
# 13301       13301                   100% Juice Cranberry Pomegranate
# 37510       37506           Free Ride Hibiscus Brew Herbal Refresher
# 6389         6389                          Freshly Squeezed Lemonade
# 22181       22180                      Lentil Sage Vegan Deli Slices
# 35639       35635                           Half & Half Lemonade Tea
# 1963         1963                              Organic Pregnancy Tea
# ...

# %%
## The previous dataframe that has been created df_party has 7650 rows

# %% [markdown]
# #### Finding info on user_id 1

# %%
# Finding info on the user_id 1
info_user_1 = df_ords[df_ords['user_id']=='1']

# %%
info_user_1.describe()
# Out:
#        order_amount  days_since_prior_order
# count     11.000000               10.000000
# mean       6.000000               19.000000
# std        3.316625                9.030811
# min        1.000000                0.000000
# 25%        3.500000               14.250000
# 50%        6.000000               19.500000
# 75%        8.500000               26.250000
# max       11.000000               30.000000

# %%
## It seems that some info on user 1 are missing

# %% [markdown]
# #### Exporting df_ords dataframe as orders_wrangled.csv and df_dep_t_new as departments_wrangled.csv

# %%
df_ords.to_csv(os.path.join(path, '02 Data','Prepared Data', 'orders_wrangled.csv')) ## exporting df_ords

# %%
df_dep_t_new.to_csv(os.path.join(path, '02 Data','Prepared Data', 'departments_wrangled.csv')) ## exporting df_dep_t_new

# %%
print(df_ords["orders_day_of_week"].dtype)
# Out:
# object

# %%
df_prods.dtypes
# Out:
# product_id         int64
# product_name      object
# aisle_id           int64
# department_id      int64
# prices           float64
# dtype: object

# %%
df_ords.dtypes
# Out:
# order_id                   object
# user_id                    object
# order_amount                int64
# orders_day_of_week         object
# order_hour_of_day          object
# days_since_prior_order    float64
# dtype: object
