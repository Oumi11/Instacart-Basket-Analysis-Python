# %% [markdown]
# # Table of content

# %% [markdown]
# #### Importing librairies and dataframe

# %%
# Importing librairies
import pandas as pd
import numpy as np
import os

# %%
path = r'C:\Users\salmi\Desktop\Projects\Achievement 4\Instacart Basket Analysis'

# %%
#Importing dataframe ords_prods_merge_2
ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data', 'Prepared Data', 'ords_prods_merge_correct.pkl'))

# %%
# Creating a subset
df = ords_prods_merge [:1000000]

# %%
df.shape
# Out:
# (1000000, 18)

# %%
df.head()
# Out:
#   order_id user_id  order_amount orders_day_of_week order_hour_of_day  \
# 0  2539329       1             1                  2                 8
# 1  2539329       1             1                  2                 8
# 2  2539329       1             1                  2                 8
# 3  2539329       1             1                  2                 8
# 4  2539329       1             1                  2                 8
#
#    days_since_prior_order product_id  add_to_cart_order  reordered  \
# 0                     NaN        196                  1          0
# 1                     NaN      14084                  2          0
# 2                     NaN      12427                  3          0
# 3                     NaN      26088                  4          0
# 4                     NaN      26405                  5          0
#
#                               product_name aisle_id department_id  prices  \
# ...

# %%
df.dtypes
# Out:
# order_id                    object
# user_id                     object
# order_amount                 int64
# orders_day_of_week          object
# order_hour_of_day           object
# days_since_prior_order     float64
# product_id                  object
# add_to_cart_order            int64
# reordered                    int64
# product_name                object
# aisle_id                    object
# department_id               object
# prices                     float64
# _merge                    category
# price_range_loc             object
# busiest_day                 object
# busiest_days                object
# busiest_period_of_day       object
# dtype: object

# %%
df.groupby('product_name')

# %%
df.groupby('department_id').agg({'order_amount': ['mean']})
# Out:
#               order_amount
#                       mean
# department_id
# 1                14.800024
# 10               20.091818
# 11               16.482026
# 12               15.615061
# 13               16.484023
# 14               17.524632
# 15               15.691875
# 16               18.014071
# 17               16.150593
# 18               19.602850
# 19               17.631340
# 2                17.091743
# 20               17.138607
# 21               21.956893
# 3                17.913544
# 4                17.893092
# 5                15.214270
# 6                15.382135
# 7                17.694027
# 8                16.458105
# 9                15.957363

# %%
df.groupby('department_id')['order_amount'].mean()
# Out:
# department_id
# 1     14.800024
# 10    20.091818
# 11    16.482026
# 12    15.615061
# 13    16.484023
# 14    17.524632
# 15    15.691875
# 16    18.014071
# 17    16.150593
# 18    19.602850
# 19    17.631340
# 2     17.091743
# 20    17.138607
# 21    21.956893
# 3     17.913544
# 4     17.893092
# 5     15.214270
# 6     15.382135
# 7     17.694027
# 8     16.458105
# 9     15.957363
# Name: order_amount, dtype: float64

# %%
# Multiple aggregation
df.groupby('department_id').agg({'order_amount': ['mean', 'min', 'max']})
# Out:
#               order_amount
#                       mean min max
# department_id
# 1                14.800024   1  99
# 10               20.091818   1  99
# 11               16.482026   1  99
# 12               15.615061   1  99
# 13               16.484023   1  99
# 14               17.524632   1  99
# 15               15.691875   1  99
# 16               18.014071   1  99
# 17               16.150593   1  99
# 18               19.602850   1  99
# 19               17.631340   1  99
# 2                17.091743   1  98
# 20               17.138607   1  99
# 21               21.956893   1  97
# 3                17.913544   1  99
# 4                17.893092   1  99
# 5                15.214270   1  99
# 6                15.382135   1  99
# 7                17.694027   1  99
# 8                16.458105   1  91
# 9                15.957363   1  99

# %% [markdown]
# #### Aggregating Data with Transform

# %%
# Spliting the data into groups
ords_prods_merge.groupby('user_id')['order_amount'].max()
# Out:
# user_id
# 1        10
# 10        5
# 100       5
# 1000      7
# 10000    72
#          ..
# 99995     5
# 99996    12
# 99997     3
# 99998     5
# 99999    34
# Name: order_amount, Length: 206209, dtype: int64

# %%
# Applying the transform function to generate max orders for each user
ords_prods_merge['max_order'] = ords_prods_merge.groupby(['user_id'])['order_amount'].transform('max')

# %%
ords_prods_merge.head(100)
# Out:
#    order_id user_id  order_amount orders_day_of_week order_hour_of_day  \
# 0   2539329       1             1                  2                 8
# 1   2539329       1             1                  2                 8
# 2   2539329       1             1                  2                 8
# 3   2539329       1             1                  2                 8
# 4   2539329       1             1                  2                 8
# ..      ...     ...           ...                ...               ...
# 95   738281       2             4                  2                10
# 96  1673511       2             5                  3                11
# 97  1673511       2             5                  3                11
# 98  1673511       2             5                  3                11
# 99  1673511       2             5                  3                11
#
#     days_since_prior_order product_id  add_to_cart_order  reordered  \
# ...

# %%
pd.options.display.max_rows = None

# %%
ords_prods_merge.head(100)
# Out:
#    order_id user_id  order_amount orders_day_of_week order_hour_of_day  \
# 0   2539329       1             1                  2                 8
# 1   2539329       1             1                  2                 8
# 2   2539329       1             1                  2                 8
# 3   2539329       1             1                  2                 8
# 4   2539329       1             1                  2                 8
# 5   2398795       1             2                  3                 7
# 6   2398795       1             2                  3                 7
# 7   2398795       1             2                  3                 7
# 8   2398795       1             2                  3                 7
# 9   2398795       1             2                  3                 7
# 10  2398795       1             2                  3                 7
# 11   473747       1             3                  3                12
# ...

# %% [markdown]
# #### Deriving columns with loc()

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] > 40, 'loyalty_flag'] = 'Loyal customer'

# %%
ords_prods_merge.loc[(ords_prods_merge['max_order'] <= 40) & (ords_prods_merge['max_order'] > 10), 'loyalty_flag'] = 'Regular customer'

# %%
ords_prods_merge.loc[ords_prods_merge['max_order'] <= 10, 'loyalty_flag'] = 'New customer'

# %%
ords_prods_merge['loyalty_flag'].value_counts(dropna = False)
# Out:
# loyalty_flag
# Regular customer    15876776
# Loyal customer      10284093
# New customer         6243990
# Name: count, dtype: int64

# %%
ords_prods_merge[['user_id', 'loyalty_flag', 'order_amount','max_order']].head(60)
# Out:
#    user_id      loyalty_flag  order_amount  max_order
# 0        1      New customer             1         10
# 1        1      New customer             1         10
# 2        1      New customer             1         10
# 3        1      New customer             1         10
# 4        1      New customer             1         10
# 5        1      New customer             2         10
# 6        1      New customer             2         10
# 7        1      New customer             2         10
# 8        1      New customer             2         10
# 9        1      New customer             2         10
# 10       1      New customer             2         10
# 11       1      New customer             3         10
# 12       1      New customer             3         10
# 13       1      New customer             3         10
# 14       1      New customer             3         10
# 15       1      New customer             3         10
# ...

# %% [markdown]
# ## Exporting data frame

# %%
ords_prods_merge.to_pickle(os.path.join(path, '02 Data','Prepared Data', 'ords_prods_merge_3.pkl'))
